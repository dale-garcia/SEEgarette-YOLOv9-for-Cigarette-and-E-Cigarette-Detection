# %% [markdown]
# # How to Train YOLOv9 on a Custom Dataset
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/WongKinYiu/yolov9)
# [![arXiv](https://img.shields.io/badge/arXiv-2402.13616-b31b1b.svg)](https://arxiv.org/pdf/2402.13616.pdf)
#
# <br>
#
# ![YOLOv9 Benchmark](https://storage.googleapis.com/com-roboflow-marketing/notebooks/examples/yolov9-benchmark.jpeg)

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Mon Jul 15 21:06:19 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Clone and Install

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 325 (delta 159), reused 156 (delta 156), pack-reused 107
# Receiving objects: 100% (325/325), 2.23 MiB | 8.17 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 67.2 MB/s eta 0:00:00

# %% [markdown]
# **NOTE:** Let's install additional packages that will be useful later on.

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.6 MB/s eta 0:00:00

# %% [markdown]
# ## Imports

# %%
import roboflow

from IPython.display import Image

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions yolov9-s and yolov9-m are also mentioned, but the weights for these models are not yet available in the YOLOv9 repository.

# %%
# !mkdir -p {HOME}/weights

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 Jul 15 21:09 .
# drwxr-xr-x 1 root root      4096 Jul 15 21:08 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Download example data

# %%
# !mkdir -p {HOME}/data

# %%
SOURCE_IMAGE_PATH = "Screenshot_70.png"

# %% [markdown]
# ## Detection with pre-trained COCO model

# %% [markdown]
# ### gelan-c

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source /content/yolov9/Screenshot_70.png --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/yolov9/Screenshot_70.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients, 102.8 GFLOPs
# Traceback (most recent call last):
#   File "/content/yolov9/detect.py", line 232, in <module>
#     main(opt)
#   File "/content/yolov9/detect.py", line 227, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov9/detect.py", line 81, in run
#     dataset = LoadImages(source, img_size=imgsz, stride=stride, auto=pt, vid_stride=vid_stride)
#   File "/content/yolov9/utils/dataloaders.py", line 250, in __init__
#     raise FileNotFoundError(f'{p} does not exist')
# FileNotFoundError: /content/yolov9/Screenshot_70.png does not exist

# %% [markdown]
# **NOTE:** By default, the results of each subsequent inference sessions are saved in `{HOME}/yolov9/runs/detect/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp4/", width=600)

# %% [markdown]
# ## yolov9-e

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source /content/yolov9/Screenshot_70.png --device 0
# Out:
# detect: weights=['/content/weights/yolov9-e.pt'], source=/content/yolov9/Screenshot_70.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# Traceback (most recent call last):
#   File "/content/yolov9/detect.py", line 232, in <module>
#     main(opt)
#   File "/content/yolov9/detect.py", line 227, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov9/detect.py", line 81, in run
#     dataset = LoadImages(source, img_size=imgsz, stride=stride, auto=pt, vid_stride=vid_stride)
#   File "/content/yolov9/utils/dataloaders.py", line 250, in __init__
#     raise FileNotFoundError(f'{p} does not exist')
# FileNotFoundError: /content/yolov9/Screenshot_70.png does not exist

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp2/dog.jpeg", width=600)

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
# %cd {HOME}/yolov9

from roboflow import Roboflow
rf = Roboflow(api_key="O12SfIc3899yYQTjo1Ju")
project = rf.workspace("firstproject-cim81").project("cigarette_detection-pdmeh")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# /content/yolov9
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in cigarette_detection-1 to yolov9:: 100%|██████████| 18629/18629 [00:02<00:00, 8153.67it/s]
# Extracting Dataset Version Zip to cigarette_detection-1 in yolov9:: 100%|██████████| 850/850 [00:00<00:00, 6573.31it/s]

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 8 --epochs 10 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-07-15 21:17:32.450302: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-15 21:17:32.450351: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-15 21:17:32.553066: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-15 21:17:32.560708: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-15 21:17:33.751082: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/cigarette_detection-1/data.yaml, hyp=hyp.scratch-high.yaml, epochs=10, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 72.4MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5492182  models.yolo.DDetect                     [2, [256, 512, 512]]
# gelan-c summary: 621 layers, 25438614 parameters, 25438598 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov9/cigarette_detection-1/train/labels... 371 images, 2 backgrounds, 0 corrupt: 100% 371/371 [00:00<00:00, 1366.85it/s]
# train: New cache created: /content/yolov9/cigarette_detection-1/train/labels.cache
# val: Scanning /content/yolov9/cigarette_detection-1/valid/labels... 23 images, 0 backgrounds, 0 corrupt: 100% 23/23 [00:00<00:00, 231.40it/s]
# val: New cache created: /content/yolov9/cigarette_detection-1/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 10 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         0/9       5.7G      2.122      3.351      2.231          6        640: 100% 47/47 [00:32<00:00,  1.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.60s/it]
#                    all         23         51      0.378      0.426      0.364      0.163
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/9      6.53G       1.84      1.802      1.921         17        640: 100% 47/47 [00:22<00:00,  2.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.73it/s]
#                    all         23         51      0.589      0.624      0.606       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/9      6.77G      1.754      1.789        1.8         15        640: 100% 47/47 [00:22<00:00,  2.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.20it/s]
#                    all         23         51      0.606      0.622      0.687      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/9      6.77G      1.754      1.464      1.728         16        640: 100% 47/47 [00:22<00:00,  2.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.61it/s]
#                    all         23         51      0.596      0.722      0.718      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/9      6.77G      1.722      1.317      1.722          8        640: 100% 47/47 [00:22<00:00,  2.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.69it/s]
#                    all         23         51      0.698      0.664      0.658      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/9      6.77G      1.646      1.187      1.686         12        640: 100% 47/47 [00:21<00:00,  2.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.36it/s]
#                    all         23         51      0.817      0.703      0.799      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         6/9      6.77G      1.663      1.151       1.69         16        640: 100% 47/47 [00:22<00:00,  2.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.65it/s]
#                    all         23         51      0.795      0.827      0.852      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         7/9      6.77G      1.624      1.085      1.614         16        640: 100% 47/47 [00:21<00:00,  2.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.77it/s]
#                    all         23         51      0.836      0.782      0.842      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         8/9      6.77G      1.568      1.003      1.585          9        640: 100% 47/47 [00:22<00:00,  2.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.19it/s]
#                    all         23         51      0.898      0.742      0.897      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         9/9      6.77G      1.528     0.9588        1.6         10        640: 100% 47/47 [00:21<00:00,  2.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.60it/s]
#                    all         23         51      0.868        0.9      0.947      0.437
#
# 10 epochs completed in 0.072 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25412502 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.65it/s]
#                    all         23         51      0.868        0.9      0.947      0.438
#              cigarette         23         25      0.871      0.811      0.918      0.397
#                 person         23         26      0.865      0.989      0.976      0.479
# Results saved to runs/train/exp

# %% [markdown]
# ## Examine Training Results

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    P_curve.png       train_batch2.jpg
# events.out.tfevents.1721078254.1423f8919471.6151.0  PR_curve.png      val_batch0_labels.jpg
# F1_curve.png					    R_curve.png       val_batch0_pred.jpg
# hyp.yaml					    results.csv       val_batch1_labels.jpg
# labels_correlogram.jpg				    results.png       val_batch1_pred.jpg
# labels.jpg					    train_batch0.jpg  weights
# opt.yaml					    train_batch1.jpg

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/confusion_matrix.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 8 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/cigarette_detection-1/data.yaml, weights=['/content/yolov9/runs/train/exp/weights/best.pt'], batch_size=8, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25412502 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/cigarette_detection-1/valid/labels.cache... 23 images, 0 backgrounds, 0 corrupt: 100% 23/23 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.05it/s]
#                    all         23         51      0.868        0.9      0.947      0.437
#              cigarette         23         25      0.871      0.811      0.919      0.397
#                 person         23         26      0.865      0.989      0.975      0.477
# Speed: 0.2ms pre-process, 56.9ms inference, 35.5ms NMS per image at shape (8, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 640 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/valid/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/cigarette_detection-1/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25412502 parameters, 0 gradients, 102.5 GFLOPs
# image 1/23 /content/yolov9/cigarette_detection-1/valid/images/855_jpg.rf.25ab53b4f4bcbf9b67f3257e0332cb54.jpg: 640x640 1 cigarette, 1 person, 51.6ms
# image 2/23 /content/yolov9/cigarette_detection-1/valid/images/873_jpg.rf.2c74f3e807a2e68861e02e6a9ec48fa5.jpg: 640x640 1 cigarette, 1 person, 42.3ms
# image 3/23 /content/yolov9/cigarette_detection-1/valid/images/894_jpg.rf.f34a9455cf6aee7c0562ad797dbe5263.jpg: 640x640 1 cigarette, 1 person, 42.2ms
# image 4/23 /content/yolov9/cigarette_detection-1/valid/images/895_jpg.rf.caaecca9712330ddc6d06e51e221a838.jpg: 640x640 1 cigarette, 1 person, 40.0ms
# image 5/23 /content/yolov9/cigarette_detection-1/valid/images/898_jpg.rf.ef2650b19d09a1dfba9038c6bdd9f5c8.jpg: 640x640 2 cigarettes, 1 person, 31.8ms
# image 6/23 /content/yolov9/cigarette_detection-1/valid/images/904_jpg.rf.0de43b8a9e0c4dbf5272d848a2d1692a.jpg: 640x640 1 cigarette, 1 person, 31.6ms
# image 7/23 /content/yolov9/cigarette_detection-1/valid/images/906_jpg.rf.ae9279bf7b168203a56fd9c7d6d6a5fe.jpg: 640x640 1 cigarette, 2 persons, 31.3ms
# image 8/23 /content/yolov9/cigarette_detection-1/valid/images/907_jpg.rf.9f75a267f505be9ede547b37dc136669.jpg: 640x640 1 cigarette, 1 person, 26.8ms
# image 9/23 /content/yolov9/cigarette_detection-1/valid/images/911_jpg.rf.a16271b95b6c2c3fbf05cec0a308eab6.jpg: 640x640 1 cigarette, 1 person, 26.2ms
# image 10/23 /content/yolov9/cigarette_detection-1/valid/images/916_jpg.rf.c72937c46c4522888592d02839811e13.jpg: 640x640 1 cigarette, 1 person, 29.3ms
# image 11/23 /content/yolov9/cigarette_detection-1/valid/images/919_jpg.rf.bfb5e2ea9ec7feddc57d2c4e1401ff14.jpg: 640x640 1 cigarette, 1 person, 26.1ms
# image 12/23 /content/yolov9/cigarette_detection-1/valid/images/922_jpg.rf.669e6f0780c87b216ecd675965fd6c2c.jpg: 640x640 1 cigarette, 1 person, 25.8ms
# image 13/23 /content/yolov9/cigarette_detection-1/valid/images/923_jpg.rf.63bc6b15ecd5056d83720a4824dd9c12.jpg: 640x640 2 cigarettes, 2 persons, 28.1ms
# image 14/23 /content/yolov9/cigarette_detection-1/valid/images/924_jpg.rf.6536bf0815b58a6effb4633544677e58.jpg: 640x640 1 cigarette, 1 person, 30.5ms
# image 15/23 /content/yolov9/cigarette_detection-1/valid/images/928_jpg.rf.be167344d2e7d648a8b704e4e5e8214a.jpg: 640x640 2 cigarettes, 2 persons, 26.1ms
# image 16/23 /content/yolov9/cigarette_detection-1/valid/images/935_jpg.rf.f13396875aa71695d73dad04ebb68074.jpg: 640x640 1 cigarette, 1 person, 24.9ms
# image 17/23 /content/yolov9/cigarette_detection-1/valid/images/937_jpg.rf.49f889c25e673aa77439ff8da9db3363.jpg: 640x640 3 cigarettes, 3 persons, 27.9ms
# image 18/23 /content/yolov9/cigarette_detection-1/valid/images/970_jpg.rf.f4f6a771f42ed2fc378b2cd66b7d0516.jpg: 640x640 1 cigarette, 1 person, 28.5ms
# image 19/23 /content/yolov9/cigarette_detection-1/valid/images/990_jpg.rf.0b7f6173e35bee0d825a1c1c00827288.jpg: 640x640 2 cigarettes, 1 person, 24.8ms
# image 20/23 /content/yolov9/cigarette_detection-1/valid/images/IMG_4363_JPG_jpg.rf.cee19aa46dc340b6d4f007eba58d0ebe.jpg: 640x640 1 cigarette, 1 person, 25.6ms
# image 21/23 /content/yolov9/cigarette_detection-1/valid/images/IMG_4367_JPG_jpg.rf.25e98c8a5e1624c032c9bef7ae21ecd3.jpg: 640x640 1 cigarette, 1 person, 24.9ms
# image 22/23 /content/yolov9/cigarette_detection-1/valid/images/IMG_4370_JPG_jpg.rf.1bc65f2232b2eeb9d0b484568579460c.jpg: 640x640 1 cigarette, 1 person, 26.1ms
# image 23/23 /content/yolov9/cigarette_detection-1/valid/images/IMG_4371_JPG_jpg.rf.cca6896c25dc49e8b5dc2fddffb6cc32.jpg: 640x640 1 cigarette, 1 person, 24.9ms
# Speed: 0.6ms pre-process, 30.3ms inference, 42.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp3/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
